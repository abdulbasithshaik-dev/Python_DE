# %%
from pydantic import BaseModel,Field,EmailStr
from typing import Optional,Literal

class employee(BaseModel):
    name:str = Field(...,min_length=3,max_length=50)
    age:int = Field(...,gt=18,lt=60)
    email :EmailStr =Field(...,description="Employee email address")
    department:Optional[str] = None
    gender: Literal['male','female','other'] = Field(...,description="Employee gender")

obj=employee(**{"name":"shaik","age":30,"email":"shaik@example.com","department":"IT","gender":"male"})
print(obj)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[9], line 11
#       7     email :EmailStr =Field(...,description="Employee email address")
#       8     department:Optional[str] = None
#       9     gender: Literal['male','female','other'] = Field(...,description="Employee gender")
#      10
# ---> 11 obj=employee(**{"age":30,"email":"shaik@example.com","gender":"male"})
#      12 print(obj)
#
# File d:\SHAIK\Python_DE\.venv\Lib\site-packages\pydantic\main.py:263, in BaseModel.__init__(self, **data)
#     261 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     262 __tracebackhide__ = True
# --> 263 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     264 if self is not validated_self:
#     265     warnings.warn(
#     266         'A custom validator is returning a value other than `self`.\n'
#     267         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     268         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     269         stacklevel=2,
#     270     )
#
# ValidationError: 1 validation error for employee
# name
#   Field required [type=missing, input_value={'age': 30, 'email': 'sha....com', 'gender': 'male'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/missing
